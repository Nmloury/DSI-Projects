# %%
import numpy as np
import pandas as pd

# %%
college = pd.read_csv('Colleges_in_San_Francisco__2011_.csv')
schools = pd.read_csv('Schools.csv')
business = pd.read_csv('./business_permits/Registered_Business_Locations_-_San_Francisco.csv')
survey = pd.read_csv('./city_survey/San_Francisco_City_Survey_Data_1996-2015.csv')
eviction = pd.read_csv('./evictions/Eviction_Notices.csv')
film = pd.read_csv('./film_locations/Film_Locations_in_San_Francisco.csv')
fire = pd.read_csv('./fire_violations/Fire_Violations.csv')
mobilefood = pd.read_csv('./mobile_food/Mobile_Food_Facility_Permit.csv')
mobilefoodsched = pd.read_csv('./mobile_food/Mobile_Food_Schedule.csv')
crime = pd.read_csv('./sf_crime/SFPD_Incidents_-_from_1_January_2003.csv')
health = pd.read_csv('./yelp_sf_healthcode_violations/yelp/violations_words.csv')
neighborhoods = pd.read_csv('./yelp_sf_healthcode_violations/sfneighborhoods.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2705: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
healthbiz = pd.read_csv('./yelp_sf_healthcode_violations/yelp/businesses.csv')
healthleg = pd.read_csv('./yelp_sf_healthcode_violations/yelp/legend.csv')

# %%
zillowlist = pd.read_csv('../zillow/Neighborhood_MedianListingPricePerSqft_AllHomes.csv')
zillowsold = pd.read_csv('../zillow/Neighborhood_MedianSoldPricePerSqft_AllHomes.csv')

# %%
college.columns
college
# Out:
#     ID                                        Institution        Campus  \
# 0   22   University of California Hastings College of Law           NaN
# 1   23   University of California Hastings College of Law           NaN
# 2   24   University of California Hastings College of Law           NaN
# 3   25                          Academy of Art University           NaN
# 4   26                          Academy of Art University           NaN
# 5   27                          Academy of Art University           NaN
# 6   28                          Academy of Art University           NaN
# 7   29                          Academy of Art University           NaN
# 8   30                          Academy of Art University           NaN
# 9   31                          Academy of Art University           NaN
# 10  32                          Academy of Art University           NaN
# 11  33                          Academy of Art University           NaN
# ...

# %%
schools.columns
# Out:
# Index([u'Campus Name', u'CCSF Entity', u'Lower Grade', u'Upper Grade',
#        u'Grade Range', u'Category', u'Map Label', u'Lower Age', u'Upper Age',
#        u'General Type', u'CDS Code', u'Campus Address', u'Supervisor District',
#        u'County FIPS', u'County Name', u'Location 1'],
#       dtype='object')

# %%
business.columns
# Out:
# Index([u'Location_ID', u'Business_Account_Number', u'Ownership_Name',
#        u'DBA Name', u'Street_Address', u'City', u'State', u'Zip_Code',
#        u'Business_Start_Date', u'Business_End_Date', u'Location Start Date',
#        u'Location_End_Date', u'Mail_Address', u'Mail_City_State_Zip',
#        u'Business_Location'],
#       dtype='object')

# %%
survey.columns
# Out:
# Index([u'id', u'year', u'mode', u'language', u'finweigh', u'swclnbrd',
#        u'swclcity', u'stclnbrd', u'stclcity', u'stpvnbrd',
#        ...
#        u'mixed_1', u'mixed_2', u'mixed_3', u'mixed_4', u'prpdother',
#        u'primlang_1', u'primlang_2', u'primlang_3', u'primlang_4',
#        u'emplytype'],
#       dtype='object', length=276)

# %%
print survey.year.min()
print survey.year.max()
# Out:
# 1996
# 2015

# %%
print eviction.columns
# Out:
# Index([u'Eviction ID', u'Address', u'City', u'State',
#        u'Eviction Notice Source Zipcode', u'File Date', u'Non Payment',
#        u'Breach', u'Nuisance', u'Illegal Use', u'Failure to Sign Renewal',
#        u'Access Denial', u'Unapproved Subtenant', u'Owner Move In',
#        u'Demolition', u'Capital Improvement', u'Substantial Rehab',
#        u'Ellis Act WithDrawal', u'Condo Conversion', u'Roommate Same Unit',
#        u'Other Cause', u'Late Payments', u'Lead Remediation', u'Development',
#        u'Good Samaritan Ends', u'Constraints Date', u'Supervisor District',
#        u'Neighborhoods - Analysis Boundaries', u'Location'],
#       dtype='object')

# %%
print eviction['File Date'].min()
print eviction['File Date'].max()
# Out:
# 01/01/2011
# 12/31/2015

# %%
fire.columns
# Out:
# Index([u'Violation Id', u'Violation Number', u'Violation Date',
#        u'Violation Item', u'Violation Item Description', u'Citation Number',
#        u'Corrective Action', u'Inspection Number', u'Address', u'Zipcode',
#        u'Battalion', u'Station Area', u'Fire Prevention District', u'Status',
#        u'Close Date', u'Supervisor District', u'Neighborhood  District',
#        u'Location'],
#       dtype='object')

# %%
print fire['Violation Date'].min()
# Out:
# 01/02/2007

# %%
print fire['Violation Date'].max()
# Out:
# 12/31/2014

# %%
print mobilefood.columns
# Out:
# Index([u'locationid', u'Applicant', u'FacilityType', u'cnn',
#        u'LocationDescription', u'Address', u'blocklot', u'block', u'lot',
#        u'permit', u'Status', u'FoodItems', u'X', u'Y', u'Latitude',
#        u'Longitude', u'Schedule', u'dayshours', u'NOISent', u'Approved',
#        u'Received', u'PriorPermit', u'ExpirationDate', u'Location'],
#       dtype='object')

# %%
print mobilefoodsched.columns
# Out:
# Index([u'DayOrder', u'DayOfWeekStr', u'starttime', u'endtime', u'permit',
#        u'PermitLocation', u'locationdesc', u'optionaltext', u'locationid',
#        u'scheduleid', u'start24', u'end24', u'CNN', u'Addr_Date_Create',
#        u'Addr_Date_Modified', u'block', u'lot', u'ColdTruck', u'Applicant',
#        u'X', u'Y', u'Latitude', u'Longitude', u'Location'],
#       dtype='object')

# %%
print crime.columns
# Out:
# Index([u'IncidntNum', u'Category', u'Descript', u'DayOfWeek', u'Date', u'Time',
#        u'PdDistrict', u'Resolution', u'Address', u'X', u'Y', u'Location',
#        u'PdId'],
#       dtype='object')

# %%
print crime.Date.min()
print crime.Date.max()
# Out:
# 01/01/2003
# 12/31/2015

# %%
print crime.shape
# Out:
# (1945294, 13)

# %%
print health.columns
# Out:
# Index([u'business_id', u'score', u'date', u'type', u'violation_count',
#        u'days_since_first_violation', u'name', u'address', u'city', u'state',
#        ...
#        u'washed fruits', u'wastewater', u'wastewater contamination',
#        u'wastewater disposal', u'water', u'water running', u'wiping',
#        u'wiping cloths', u'worker', u'worker safety'],
#       dtype='object', length=393)

# %%
healthbiz.columns
# Out:
# Index([u'business_id', u'name', u'address', u'city', u'state', u'postal_code',
#        u'latitude', u'longitude', u'phone_number'],
#       dtype='object')

# %%
healthleg.columns
# Out:
# Index([u'Minimum_Score', u'Maximum_Score', u'Description'], dtype='object')

# %%
zillowlist[zillowlist.City == 'San Fancisco'].columns
zillowlist[zillowlist.City == 'San Francisco']
# Out:
#           RegionName           City State          Metro     CountyName  \
# 115          Mission  San Francisco    CA  San Francisco  San Francisco
# 523  South of Market  San Francisco    CA  San Francisco  San Francisco
# 781      South Beach  San Francisco    CA  San Francisco  San Francisco
#
#      SizeRank     2010-01     2010-02     2010-03     2010-04     ...       \
# 115       116         NaN         NaN         NaN         NaN     ...
# 523       524  634.323145  636.326194  598.866532  594.914739     ...
# 781       782  702.843262  736.344329  719.951923  718.580776     ...
#
#          2015-09      2015-10      2015-11      2015-12      2016-01  \
# 115   828.598485   886.631016   928.258488   950.206612   922.058047
# 523   960.087083   960.087083   962.552011   973.653055  1026.275345
# 781  1261.595547  1293.995859  1328.272552  1327.615780  1366.197183
#
#          2016-02      2016-03      2016-04      2016-05      2016-06
# ...

# %%
print zillowsold[zillowsold.City == 'San Francisco'].columns
zillowsold[zillowsold.City == 'San Francisco']
# Out:
# Index([u'RegionID', u'RegionName', u'City', u'State', u'Metro', u'CountyName',
#        u'SizeRank', u'1996-04', u'1996-05', u'1996-06',
#        ...
#        u'2015-09', u'2015-10', u'2015-11', u'2015-12', u'2016-01', u'2016-02',
#        u'2016-03', u'2016-04', u'2016-05', u'2016-06'],
#       dtype='object', length=250)
#       RegionID                                RegionName           City State  \
# 113     274552                                   Mission  San Francisco    CA
# 340     268020                            Bernal Heights  San Francisco    CA
# 403     117654                          Central Richmond  San Francisco    CA
# 414     268150                                 Excelsior  San Francisco    CA
# 472     272885                                   Bayview  San Francisco    CA
# 485     417497                            Central Sunset  San Francisco    CA
# 529     268114                                  Downtown  San Francisco    CA
# ...

# %%
assessor.columns
# Out:
# Index([u'PROPLOC', u'RP1NBRCDE', u'RP1PRCLID', u'RP1VOLUME', u'RP1CLACDE',
#        u'YRBLT', u'BATHS', u'BEDS', u'ROOMS', u'STOREYNO', u'UNITS',
#        u'CHGDATE', u'ZONE', u'CONSTTYPE', u'DEPTH', u'FRONT', u'SQFT', u'FBA',
#        u'LAREA', u'LOTCODE', u'REPRISDATE', u'RP1RECDAT1', u'RP1DOCNO1',
#        u'RP1DOCNO2', u'RP1TRACDE', u'OWNRPRCNT', u'EXEMPTYPE', u'RP1STACDE',
#        u'RP1EXMVL2', u'RP1EXMVL1', u'ROLLYEAR', u'RECURRSALD', u'RP1FXTVAL',
#        u'RP1IMPVAL', u'RP1LNDVAL', u'RP1PPTVAL'],
#       dtype='object')

# %%
for yr in ['2012-2013','2011-2012','2010-2011','2009-2010','2008-2009','2007-2008']:
    print yr
    assessor = pd.read_excel('./assessor_office/2016.5.11__SF ASR_Secured_Roll Data_'+yr+'.xlsx')
    assessor.to_csv('./assessor_office/assessor_data_'+yr.replace('-','_')+'.csv', index=False)
